# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os, time, shutil, sys
from pathlib import Path
from glob import glob
import numpy as np
import spikeinterface.full as si
import h5py
import matplotlib.pyplot as plt
from tqdm import tqdm

sys.path.append("/home/phornauer/Git/axon_tracking/")
from axon_tracking import spike_sorting as ss

# %%
sorter = 'kilosort2_5'
si.Kilosort2_5Sorter.set_kilosort2_5_path('/home/phornauer/Git/Kilosort_2020b')
sorter_params = si.get_default_sorter_params(si.Kilosort2_5Sorter)
sorter_params['n_jobs'] = -1
sorter_params['detect_threshold'] = 6
sorter_params['minFR'] = 0.01
sorter_params['minfr_goodchannels'] = 0.01
sorter_params['keep_good_only'] = False
sorter_params['do_correction'] = False
sorter_params['NT'] = 64*1024 + 64
# Out:
# Setting KILOSORT2_5_PATH environment variable for subprocess calls to: /home/phornauer/Git/Kilosort_2020b

# %%
path = '/net/bs-filesvr02/export/group/hierlemann/recordings/Maxtwo/phornauer/240823/T002523/Network/000002/data.raw.h5'

# %%
h5 = h5py.File(path)
stream_ids = list(h5['wells'].keys())
stream_ids
# Out:
# ['well000',
#  'well001',
#  'well002',
#  'well003',
#  'well004',
#  'well005',
#  'well006',
#  'well007',
#  'well008',
#  'well009',
#  'well010',
#  'well011',
#  'well012',
#  'well013',
#  'well014',
#  'well015',
#  'well016',
#  'well017',
#  'well018',
#  'well019',
#  'well020',
#  'well021',
#  'well022',
#  'well023']

# %%
save_root = '/net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/'
for stream_id in tqdm(stream_ids):
    rec = si.MaxwellRecordingExtractor(path, stream_id=stream_id)
    ss.clean_sorting(rec, save_root, stream_id=stream_id, sorter=sorter, sorter_params=sorter_params)
# Out:
#   0%|                                                                                                    | 0/24 [00:00<?, ?it/s]
# DURATION: 1800.06 s -- NUM. CHANNELS: 944
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well000/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 205s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.78 sec, 1 batches, 1659 spikes
#
# 65.58 sec, 101 batches, 184631 spikes
#
# 130.28 sec, 201 batches, 373481 spikes
#
# 178.45 sec, 275 batches, 511019 spikes
#
# time 185.00, Skipped shifting 275 batches.
#
# Time 188s. Optimizing templates ...
#
# 189.08 sec, 1 / 275 batches, 40 units, nspks: 3.6518, mu: 16.0277, nst0: 22, merges: 0.0000, 0.0000, 1.8000
#
# 214.97 sec, 101 / 275 batches, 39 units, nspks: 11.0390, mu: 10.0000, nst0: 10, merges: 148.4182, 0.0000, 33.9121
#
# 240.17 sec, 201 / 275 batches, 43 units, nspks: 10.7756, mu: 10.0000, nst0: 7, merges: 167.6118, 0.0000, 34.0948
#
# Elapsed time is 258.388033 seconds.
#
# Finished learning templates
#
# Time 259s. Optimizing templates ...
#
# 258.71 sec, 1 / 275 batches, 6 units, nspks: 12.0000, mu: 17.9127, nst0: 22
#
# 274.00 sec, 101 / 275 batches, 6 units, nspks: 988.0000, mu: 17.9127, nst0: 22
#
# 288.48 sec, 201 / 275 batches, 6 units, nspks: 1925.0000, mu: 17.9127, nst0: 13
#
# Elapsed time is 299.420804 seconds.
#
# Number of spikes before applying cutoff: 5290
#
# initialized spike counts
#
# Found 0 splits, checked 1/6 clusters, nccg 0
#
# Finished splitting. Found 1 splits, checked 7/7 clusters, nccg 0
#
# Removing 2549 spikes below cutoff from rez.
#
# found 4 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 526.06s
#
#
# Spike sorting elapsed time 689.8560104370117 s
#   4%|███▋                                                                                     | 1/24 [11:37<4:27:28, 697.76s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 992
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well001/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time   6s. Loading raw data and applying filters...
#
# Time 141s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.78 sec, 1 batches, 6815 spikes
#
# 76.70 sec, 101 batches, 741047 spikes
#
# 153.14 sec, 201 batches, 1476938 spikes
#
# 208.86 sec, 275 batches, 2014269 spikes
#
# time 216.63, Skipped shifting 275 batches.
#
# Time 221s. Optimizing templates ...
#
# 221.32 sec, 1 / 275 batches, 127 units, nspks: 38.0778, mu: 10.0000, nst0: 599, merges: 0.1000, 0.0000, 6.5000
#
# 259.79 sec, 101 / 275 batches, 247 units, nspks: 4319.6647, mu: 13.4727, nst0: 4302, merges: 341.7290, 0.6293, 77.8122
#
# 296.85 sec, 201 / 275 batches, 236 units, nspks: 4391.9583, mu: 12.5013, nst0: 4112, merges: 386.2781, 0.1481, 77.4729
#
# Elapsed time is 324.092555 seconds.
#
# Finished learning templates
#
# Time 325s. Optimizing templates ...
#
# 325.07 sec, 1 / 275 batches, 168 units, nspks: 4236.0000, mu: 15.1161, nst0: 6097
#
# 351.06 sec, 101 / 275 batches, 168 units, nspks: 459143.0000, mu: 15.1161, nst0: 6370
#
# 377.84 sec, 201 / 275 batches, 168 units, nspks: 915638.0000, mu: 15.1161, nst0: 6592
#
# Elapsed time is 396.582756 seconds.
#
# Number of spikes before applying cutoff: 1803278
#
# initialized spike counts
#
# merged 24 into 25
#
# merged 128 into 133
#
# merged 137 into 136
#
# merged 140 into 136
#
# merged 96 into 97
#
# merged 139 into 136
#
# merged 19 into 17
#
# merged 141 into 136
#
# merged 21 into 17
#
# merged 69 into 68
#
# merged 38 into 39
#
# merged 162 into 161
#
# merged 138 into 136
#
# merged 17 into 16
#
# merged 77 into 76
#
# merged 167 into 166
#
# Found 0 splits, checked 1/168 clusters, nccg 1
#
# Found 1 splits, checked 1/169 clusters, nccg 1
#
# Found 28 splits, checked 101/196 clusters, nccg 61
#
# Found 29 splits, checked 101/197 clusters, nccg 61
#
# Found 47 splits, checked 201/215 clusters, nccg 111
#
# Finished splitting. Found 49 splits, checked 217/217 clusters, nccg 124
#
# Removing 357795 spikes below cutoff from rez.
#
# found 131 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 614.12s
#
#
# Spike sorting elapsed time 777.596896648407 s
#   8%|███████▍                                                                                 | 2/24 [24:43<4:34:52, 749.64s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 987
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well002/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 216s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.73 sec, 1 batches, 5966 spikes
#
# 67.92 sec, 101 batches, 657983 spikes
#
# 136.16 sec, 201 batches, 1313846 spikes
#
# 186.61 sec, 275 batches, 1796492 spikes
#
# time 194.97, Skipped shifting 275 batches.
#
# Time 199s. Optimizing templates ...
#
# 199.68 sec, 1 / 275 batches, 63 units, nspks: 15.2172, mu: 10.0000, nst0: 223, merges: 2.7000, 0.0000, 4.3000
#
# 239.57 sec, 101 / 275 batches, 380 units, nspks: 3241.0529, mu: 17.2370, nst0: 4862, merges: 158.2778, 1.9233, 39.4034
#
# 282.31 sec, 201 / 275 batches, 418 units, nspks: 3500.0693, mu: 17.7203, nst0: 3015, merges: 202.4913, 1.3112, 42.0314
#
# Elapsed time is 313.615504 seconds.
#
# Finished learning templates
#
# Time 316s. Optimizing templates ...
#
# 316.65 sec, 1 / 275 batches, 373 units, nspks: 3377.0000, mu: 17.1900, nst0: 4815
#
# 346.67 sec, 101 / 275 batches, 373 units, nspks: 376315.0000, mu: 17.1900, nst0: 4454
#
# 376.75 sec, 201 / 275 batches, 373 units, nspks: 748454.0000, mu: 17.1900, nst0: 4442
#
# Elapsed time is 398.314624 seconds.
#
# Number of spikes before applying cutoff: 1451345
#
# initialized spike counts
#
# merged 357 into 355
#
# merged 116 into 105
#
# merged 274 into 273
#
# merged 149 into 290
#
# merged 350 into 351
#
# merged 280 into 281
#
# merged 91 into 86
#
# merged 110 into 105
#
# merged 147 into 47
#
# merged 117 into 114
#
# merged 314 into 313
#
# merged 315 into 313
#
# merged 12 into 7
#
# merged 132 into 133
#
# merged 37 into 45
#
# merged 107 into 105
#
# merged 112 into 109
#
# merged 250 into 249
#
# merged 31 into 51
#
# merged 363 into 369
#
# merged 216 into 220
#
# merged 358 into 355
#
# merged 113 into 114
#
# merged 362 into 369
#
# merged 204 into 205
#
# merged 78 into 77
#
# merged 284 into 282
#
# merged 9 into 4
#
# merged 251 into 249
#
# merged 265 into 248
#
# merged 65 into 64
#
# merged 54 into 100
#
# merged 188 into 185
#
# merged 106 into 114
#
# merged 90 into 86
#
# merged 47 into 48
#
# merged 254 into 351
#
# merged 356 into 355
#
# merged 236 into 237
#
# merged 21 into 20
#
# merged 109 into 114
#
# merged 282 into 283
#
# merged 177 into 171
#
# merged 100 into 59
#
# Found 0 splits, checked 1/373 clusters, nccg 0
#
# Found 2 splits, checked 101/375 clusters, nccg 24
#
# Found 19 splits, checked 201/392 clusters, nccg 66
#
# Found 34 splits, checked 301/407 clusters, nccg 108
#
# Found 48 splits, checked 401/421 clusters, nccg 161
#
# Finished splitting. Found 52 splits, checked 425/425 clusters, nccg 173
#
# Removing 306573 spikes below cutoff from rez.
#
# found 197 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 697.18s
#
#
# Spike sorting elapsed time 863.2093811035156 s
#  12%|███████████▏                                                                             | 3/24 [39:15<4:41:49, 805.23s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 1004
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well003/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 219s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.72 sec, 1 batches, 10000 spikes
#
# 64.94 sec, 101 batches, 990922 spikes
#
# 130.41 sec, 201 batches, 1981989 spikes
#
# 178.50 sec, 275 batches, 2694377 spikes
#
# time 186.80, Skipped shifting 275 batches.
#
# Time 191s. Optimizing templates ...
#
# 191.30 sec, 1 / 275 batches, 124 units, nspks: 31.4310, mu: 12.4603, nst0: 470, merges: 0.3000, 0.0000, 6.2000
#
# 235.44 sec, 101 / 275 batches, 491 units, nspks: 4813.7785, mu: 16.8903, nst0: 5047, merges: 361.6219, 0.4013, 85.5045
#
# 279.46 sec, 201 / 275 batches, 471 units, nspks: 5303.7633, mu: 15.0080, nst0: 5769, merges: 427.8588, 0.2164, 88.5302
#
# Elapsed time is 312.472967 seconds.
#
# Finished learning templates
#
# Time 315s. Optimizing templates ...
#
# 314.91 sec, 1 / 275 batches, 375 units, nspks: 5588.0000, mu: 16.5121, nst0: 8618
#
# 346.77 sec, 101 / 275 batches, 375 units, nspks: 555956.0000, mu: 16.5121, nst0: 8342
#
# 379.06 sec, 201 / 275 batches, 375 units, nspks: 1106343.0000, mu: 16.5121, nst0: 7517
#
# Elapsed time is 402.636654 seconds.
#
# Number of spikes before applying cutoff: 2246443
#
# initialized spike counts
#
# merged 190 into 189
#
# merged 371 into 255
#
# merged 93 into 170
#
# merged 315 into 314
#
# merged 188 into 189
#
# merged 41 into 116
#
# merged 35 into 52
#
# merged 89 into 167
#
# merged 113 into 112
#
# merged 269 into 228
#
# merged 243 into 242
#
# merged 76 into 229
#
# merged 205 into 204
#
# merged 136 into 159
#
# merged 39 into 38
#
# merged 198 into 196
#
# merged 86 into 88
#
# merged 316 into 335
#
# merged 146 into 147
#
# merged 234 into 68
#
# merged 104 into 103
#
# merged 246 into 247
#
# merged 264 into 266
#
# merged 196 into 132
#
# merged 199 into 197
#
# merged 244 into 242
#
# merged 87 into 88
#
# merged 208 into 261
#
# merged 221 into 220
#
# merged 85 into 88
#
# merged 257 into 258
#
# merged 348 into 349
#
# merged 10 into 9
#
# merged 57 into 58
#
# Found 0 splits, checked 1/375 clusters, nccg 0
#
# Found 8 splits, checked 101/383 clusters, nccg 36
#
# Found 15 splits, checked 201/390 clusters, nccg 81
#
# Found 16 splits, checked 201/391 clusters, nccg 81
#
# Found 22 splits, checked 301/397 clusters, nccg 127
#
# Found 33 splits, checked 401/408 clusters, nccg 170
#
# Finished splitting. Found 33 splits, checked 408/408 clusters, nccg 175
#
# Removing 655122 spikes below cutoff from rez.
#
# found 198 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 714.55s
#
#
# Spike sorting elapsed time 881.6828916072845 s
#  17%|██████████████▊                                                                          | 4/24 [54:05<4:39:35, 838.75s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 998
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well004/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 215s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.75 sec, 1 batches, 9134 spikes
#
# 65.96 sec, 101 batches, 702689 spikes
#
# 132.47 sec, 201 batches, 1386526 spikes
#
# 181.64 sec, 275 batches, 1890944 spikes
#
# time 189.49, Skipped shifting 275 batches.
#
# Time 193s. Optimizing templates ...
#
# 193.99 sec, 1 / 275 batches, 82 units, nspks: 17.3480, mu: 10.0000, nst0: 244, merges: 1.5000, 0.1000, 4.2000
#
# 231.90 sec, 101 / 275 batches, 478 units, nspks: 3159.2285, mu: 18.5070, nst0: 3145, merges: 216.0166, 0.2344, 57.3288
#
# 272.34 sec, 201 / 275 batches, 486 units, nspks: 3421.2183, mu: 18.3890, nst0: 3286, merges: 285.0216, 0.0539, 57.8790
#
# Elapsed time is 302.374645 seconds.
#
# Finished learning templates
#
# Time 305s. Optimizing templates ...
#
# 305.27 sec, 1 / 275 batches, 420 units, nspks: 4693.0000, mu: 19.0451, nst0: 5754
#
# 333.54 sec, 101 / 275 batches, 420 units, nspks: 358993.0000, mu: 19.0451, nst0: 4717
#
# 363.18 sec, 201 / 275 batches, 420 units, nspks: 708172.0000, mu: 19.0451, nst0: 3637
#
# Elapsed time is 383.924438 seconds.
#
# Number of spikes before applying cutoff: 1222487
#
# initialized spike counts
#
# merged 143 into 141
#
# merged 182 into 141
#
# merged 21 into 132
#
# merged 169 into 149
#
# merged 72 into 141
#
# merged 255 into 261
#
# merged 301 into 393
#
# merged 140 into 139
#
# merged 142 into 141
#
# merged 383 into 385
#
# merged 101 into 100
#
# merged 306 into 304
#
# merged 384 into 385
#
# merged 299 into 300
#
# merged 133 into 132
#
# merged 120 into 118
#
# merged 158 into 159
#
# merged 240 into 261
#
# merged 282 into 283
#
# merged 42 into 38
#
# merged 247 into 232
#
# merged 201 into 313
#
# merged 204 into 197
#
# merged 126 into 125
#
# merged 49 into 47
#
# merged 71 into 70
#
# merged 119 into 118
#
# merged 342 into 339
#
# merged 27 into 38
#
# merged 109 into 105
#
# merged 208 into 207
#
# merged 256 into 261
#
# merged 41 into 26
#
# merged 258 into 261
#
# merged 203 into 313
#
# merged 284 into 283
#
# merged 135 into 134
#
# merged 209 into 207
#
# merged 149 into 168
#
# merged 311 into 197
#
# merged 210 into 207
#
# merged 215 into 214
#
# merged 31 into 28
#
# merged 232 into 261
#
# merged 179 into 178
#
# merged 29 into 25
#
# merged 377 into 376
#
# merged 153 into 144
#
# merged 45 into 226
#
# merged 96 into 97
#
# merged 44 into 38
#
# merged 40 into 38
#
# merged 161 into 128
#
# merged 26 into 38
#
# merged 28 into 38
#
# merged 43 into 38
#
# merged 414 into 408
#
# merged 405 into 409
#
# merged 25 into 38
#
# merged 409 into 408
#
# merged 188 into 187
#
# merged 296 into 90
#
# merged 224 into 223
#
# Found 0 splits, checked 1/420 clusters, nccg 0
#
# Found 7 splits, checked 101/427 clusters, nccg 32
#
# Found 12 splits, checked 201/432 clusters, nccg 79
#
# Found 17 splits, checked 301/437 clusters, nccg 113
#
# Found 25 splits, checked 401/445 clusters, nccg 148
#
# Finished splitting. Found 33 splits, checked 453/453 clusters, nccg 165
#
# Removing 221610 spikes below cutoff from rez.
#
# found 209 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 678.95s
#
#
# Spike sorting elapsed time 846.7847573757172 s
#  21%|██████████████████▏                                                                    | 5/24 [1:08:20<4:27:32, 844.88s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 986
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well005/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time   6s. Loading raw data and applying filters...
#
# Time 160s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.76 sec, 1 batches, 6517 spikes
#
# 66.61 sec, 101 batches, 705320 spikes
#
# 132.20 sec, 201 batches, 1408611 spikes
#
# 180.61 sec, 275 batches, 1929173 spikes
#
# time 188.60, Skipped shifting 275 batches.
#
# Time 192s. Optimizing templates ...
#
# 193.09 sec, 1 / 275 batches, 114 units, nspks: 43.5144, mu: 10.0000, nst0: 724, merges: 2.1000, 0.0000, 6.4000
#
# 234.95 sec, 101 / 275 batches, 529 units, nspks: 4514.2611, mu: 17.5674, nst0: 4785, merges: 295.1381, 1.7627, 72.6070
#
# 280.22 sec, 201 / 275 batches, 602 units, nspks: 4829.4742, mu: 17.3913, nst0: 5679, merges: 367.3060, 0.6231, 76.5287
#
# Elapsed time is 313.085100 seconds.
#
# Finished learning templates
#
# Time 317s. Optimizing templates ...
#
# 317.21 sec, 1 / 275 batches, 522 units, nspks: 4395.0000, mu: 17.5526, nst0: 6383
#
# 351.13 sec, 101 / 275 batches, 522 units, nspks: 491765.0000, mu: 17.5526, nst0: 7777
#
# 385.06 sec, 201 / 275 batches, 522 units, nspks: 982328.0000, mu: 17.5526, nst0: 5734
#
# Elapsed time is 410.991120 seconds.
#
# Number of spikes before applying cutoff: 1927082
#
# initialized spike counts
#
# merged 8 into 5
#
# merged 58 into 57
#
# merged 71 into 64
#
# merged 439 into 437
#
# merged 40 into 471
#
# merged 330 into 321
#
# merged 436 into 448
#
# merged 447 into 437
#
# merged 308 into 307
#
# merged 298 into 197
#
# merged 61 into 64
#
# merged 397 into 399
#
# merged 484 into 485
#
# merged 474 into 39
#
# merged 323 into 321
#
# merged 6 into 5
#
# merged 55 into 64
#
# merged 469 into 467
#
# merged 454 into 452
#
# merged 75 into 74
#
# merged 66 into 60
#
# merged 59 into 64
#
# merged 87 into 88
#
# merged 63 into 60
#
# merged 365 into 367
#
# merged 23 into 24
#
# merged 85 into 82
#
# merged 326 into 325
#
# merged 13 into 68
#
# merged 468 into 467
#
# merged 329 into 325
#
# merged 316 into 319
#
# merged 473 into 472
#
# merged 229 into 226
#
# merged 89 into 88
#
# merged 263 into 273
#
# merged 99 into 94
#
# merged 228 into 226
#
# merged 435 into 437
#
# merged 227 into 226
#
# merged 272 into 273
#
# merged 180 into 175
#
# merged 88 into 82
#
# merged 440 into 437
#
# merged 412 into 390
#
# merged 327 into 328
#
# merged 28 into 19
#
# merged 72 into 68
#
# merged 39 into 472
#
# merged 209 into 210
#
# merged 267 into 273
#
# merged 471 into 472
#
# merged 86 into 82
#
# merged 446 into 437
#
# merged 476 into 475
#
# merged 328 into 325
#
# merged 311 into 312
#
# merged 218 into 403
#
# merged 19 into 24
#
# merged 453 into 452
#
# merged 256 into 254
#
# merged 74 into 73
#
# merged 18 into 24
#
# merged 319 into 325
#
# merged 406 into 403
#
# merged 62 into 68
#
# merged 299 into 197
#
# merged 371 into 367
#
# merged 92 into 91
#
# merged 479 into 480
#
# merged 356 into 354
#
# merged 321 into 325
#
# merged 254 into 258
#
# merged 355 into 354
#
# merged 115 into 114
#
# merged 451 into 450
#
# merged 300 into 301
#
# merged 257 into 258
#
# merged 314 into 315
#
# Found 0 splits, checked 1/522 clusters, nccg 0
#
# Found 14 splits, checked 101/536 clusters, nccg 26
#
# Found 22 splits, checked 201/544 clusters, nccg 44
#
# Found 36 splits, checked 301/558 clusters, nccg 80
#
# Found 43 splits, checked 401/565 clusters, nccg 110
#
# Found 50 splits, checked 501/572 clusters, nccg 150
#
# Finished splitting. Found 60 splits, checked 582/582 clusters, nccg 180
#
# Removing 450275 spikes below cutoff from rez.
#
# found 257 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 678.75s
#
#
# Spike sorting elapsed time 845.9163162708282 s
#  25%|█████████████████████▊                                                                 | 6/24 [1:22:35<4:14:25, 848.07s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 982
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well006/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time   6s. Loading raw data and applying filters...
#
# Time 161s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.72 sec, 1 batches, 475 spikes
#
# 65.76 sec, 101 batches, 48617 spikes
#
# 130.96 sec, 201 batches, 98022 spikes
#
# 179.69 sec, 275 batches, 133948 spikes
#
# time 186.08, Skipped shifting 275 batches.
#
# Time 190s. Optimizing templates ...
#
# 190.32 sec, 1 / 275 batches, 11 units, nspks: 1.1421, mu: 18.1865, nst0: 9, merges: 0.0000, 0.0000, 0.2000
#
# 215.65 sec, 101 / 275 batches, 7 units, nspks: 0.4592, mu: 10.0000, nst0: 0, merges: 35.7232, 0.0000, 8.3961
#
# 240.07 sec, 201 / 275 batches, 9 units, nspks: 0.5904, mu: 10.0000, nst0: 0, merges: 39.5297, 0.0000, 8.2601
#
# Elapsed time is 258.166331 seconds.
#
# ----------------------------------------Index in position 1 is invalid. Array indices must be positive integers or logical values.
# Error running kilosort2_5
# Spike sorting error trace:
# Traceback (most recent call last):
#   File "/home/phornauer/si_test/spikeinterface/src/spikeinterface/sorters/basesorter.py", line 254, in run_from_folder
#     SorterClass._run_from_folder(sorter_output_folder, sorter_params, verbose)
#   File "/home/phornauer/si_test/spikeinterface/src/spikeinterface/sorters/external/kilosortbase.py", line 215, in _run_from_folder
#     raise Exception(f"{cls.sorter_name} returned a non-zero exit code")
# Exception: kilosort2_5 returned a non-zero exit code
#
# Spike sorting failed. You can inspect the runtime trace in /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well006/spikeinterface_log.json.
#  29%|█████████████████████████▍                                                             | 7/24 [1:32:42<3:37:59, 769.40s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 960
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well007/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 222s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.72 sec, 1 batches, 824 spikes
#
# 65.86 sec, 101 batches, 76724 spikes
#
# 130.81 sec, 201 batches, 153797 spikes
#
# 178.85 sec, 275 batches, 209514 spikes
#
# time 185.01, Skipped shifting 275 batches.
#
# Time 189s. Optimizing templates ...
#
# 189.17 sec, 1 / 275 batches, 15 units, nspks: 1.4045, mu: 15.1477, nst0: 9, merges: 0.0000, 0.0000, 0.6000
#
# 214.52 sec, 101 / 275 batches, 14 units, nspks: 0.9184, mu: 10.0000, nst0: 0, merges: 59.4752, 0.0000, 12.9204
#
# 239.36 sec, 201 / 275 batches, 11 units, nspks: 0.7216, mu: 10.0000, nst0: 0, merges: 67.1262, 0.0000, 13.2852
#
# Elapsed time is 257.436284 seconds.
#
# ----------------------------------------Index in position 1 is invalid. Array indices must be positive integers or logical values.
# Error running kilosort2_5
# Spike sorting error trace:
# Traceback (most recent call last):
#   File "/home/phornauer/si_test/spikeinterface/src/spikeinterface/sorters/basesorter.py", line 254, in run_from_folder
#     SorterClass._run_from_folder(sorter_output_folder, sorter_params, verbose)
#   File "/home/phornauer/si_test/spikeinterface/src/spikeinterface/sorters/external/kilosortbase.py", line 215, in _run_from_folder
#     raise Exception(f"{cls.sorter_name} returned a non-zero exit code")
# Exception: kilosort2_5 returned a non-zero exit code
#
# Spike sorting failed. You can inspect the runtime trace in /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well007/spikeinterface_log.json.
#  33%|█████████████████████████████                                                          | 8/24 [1:43:41<3:15:45, 734.07s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 988
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well008/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 218s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.73 sec, 1 batches, 6926 spikes
#
# 65.24 sec, 101 batches, 775818 spikes
#
# 130.88 sec, 201 batches, 1558212 spikes
#
# 179.51 sec, 275 batches, 2124398 spikes
#
# time 187.55, Skipped shifting 275 batches.
#
# Time 191s. Optimizing templates ...
#
# 191.95 sec, 1 / 275 batches, 42 units, nspks: 5.4527, mu: 10.0000, nst0: 55, merges: 1.3000, 0.0000, 2.6000
#
# 229.89 sec, 101 / 275 batches, 376 units, nspks: 4004.2304, mu: 17.6394, nst0: 4835, merges: 198.6530, 0.3368, 47.2880
#
# 269.96 sec, 201 / 275 batches, 410 units, nspks: 4342.5238, mu: 17.0411, nst0: 3394, merges: 238.3565, 0.2440, 47.8837
#
# Elapsed time is 300.726517 seconds.
#
# Finished learning templates
#
# Time 303s. Optimizing templates ...
#
# 303.51 sec, 1 / 275 batches, 400 units, nspks: 3956.0000, mu: 17.2409, nst0: 5255
#
# 333.35 sec, 101 / 275 batches, 400 units, nspks: 461660.0000, mu: 17.2409, nst0: 4671
#
# 363.85 sec, 201 / 275 batches, 400 units, nspks: 927960.0000, mu: 17.2409, nst0: 6211
#
# Elapsed time is 386.344200 seconds.
#
# Number of spikes before applying cutoff: 1658986
#
# initialized spike counts
#
# merged 103 into 71
#
# merged 175 into 174
#
# merged 97 into 96
#
# merged 348 into 350
#
# merged 17 into 16
#
# merged 70 into 69
#
# merged 171 into 170
#
# merged 66 into 71
#
# merged 147 into 146
#
# merged 24 into 21
#
# merged 106 into 71
#
# merged 255 into 259
#
# merged 307 into 315
#
# merged 60 into 65
#
# merged 297 into 296
#
# merged 23 into 21
#
# merged 112 into 113
#
# merged 125 into 47
#
# merged 353 into 352
#
# merged 365 into 366
#
# merged 271 into 270
#
# merged 67 into 65
#
# merged 359 into 360
#
# merged 398 into 396
#
# merged 335 into 313
#
# merged 104 into 105
#
# merged 314 into 313
#
# merged 74 into 75
#
# merged 299 into 298
#
# merged 183 into 184
#
# merged 323 into 336
#
# merged 272 into 270
#
# merged 355 into 360
#
# merged 113 into 109
#
# merged 69 into 71
#
# merged 68 into 65
#
# merged 298 into 296
#
# merged 360 into 357
#
# merged 259 into 254
#
# merged 309 into 308
#
# merged 105 into 71
#
# merged 312 into 313
#
# merged 63 into 65
#
# merged 19 into 20
#
# merged 29 into 28
#
# merged 308 into 313
#
# merged 12 into 13
#
# Found 0 splits, checked 1/400 clusters, nccg 1
#
# Found 6 splits, checked 101/406 clusters, nccg 47
#
# Found 17 splits, checked 201/417 clusters, nccg 94
#
# Found 23 splits, checked 301/423 clusters, nccg 135
#
# Found 34 splits, checked 401/434 clusters, nccg 182
#
# Finished splitting. Found 40 splits, checked 440/440 clusters, nccg 201
#
# Removing 282821 spikes below cutoff from rez.
#
# found 213 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 689.92s
#
#
# Spike sorting elapsed time 848.6944015026093 s
#  38%|████████████████████████████████▋                                                      | 9/24 [1:57:57<3:13:06, 772.42s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 991
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well009/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time   6s. Loading raw data and applying filters...
#
# Time 168s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.70 sec, 1 batches, 10000 spikes
#
# 71.18 sec, 101 batches, 808789 spikes
#
# 137.99 sec, 201 batches, 1606946 spikes
#
# 187.54 sec, 275 batches, 2197768 spikes
#
# time 195.76, Skipped shifting 275 batches.
#
# Time 200s. Optimizing templates ...
#
# 200.29 sec, 1 / 275 batches, 97 units, nspks: 33.2558, mu: 10.0000, nst0: 541, merges: 1.0000, 0.0000, 4.9000
#
# 242.14 sec, 101 / 275 batches, 467 units, nspks: 3945.2371, mu: 17.1045, nst0: 3368, merges: 253.7820, 0.4694, 63.4151
#
# 285.57 sec, 201 / 275 batches, 469 units, nspks: 4579.3829, mu: 15.9381, nst0: 6219, merges: 323.5126, 0.3411, 67.6964
#
# Elapsed time is 318.613604 seconds.
#
# Finished learning templates
#
# Time 321s. Optimizing templates ...
#
# 321.56 sec, 1 / 275 batches, 428 units, nspks: 5630.0000, mu: 16.6758, nst0: 7701
#
# 352.36 sec, 101 / 275 batches, 428 units, nspks: 474334.0000, mu: 16.6758, nst0: 5465
#
# 383.27 sec, 201 / 275 batches, 428 units, nspks: 942569.0000, mu: 16.6758, nst0: 6983
#
# Elapsed time is 406.921042 seconds.
#
# Number of spikes before applying cutoff: 1848514
#
# initialized spike counts
#
# merged 185 into 183
#
# merged 131 into 139
#
# merged 110 into 109
#
# merged 219 into 47
#
# merged 114 into 112
#
# merged 144 into 198
#
# merged 385 into 384
#
# merged 338 into 352
#
# merged 307 into 308
#
# merged 100 into 99
#
# merged 376 into 380
#
# merged 391 into 390
#
# merged 113 into 112
#
# merged 337 into 352
#
# merged 381 into 380
#
# merged 289 into 428
#
# merged 322 into 320
#
# merged 418 into 419
#
# merged 54 into 53
#
# merged 332 into 36
#
# merged 66 into 65
#
# merged 372 into 367
#
# merged 364 into 363
#
# merged 280 into 279
#
# merged 228 into 225
#
# merged 81 into 80
#
# merged 409 into 407
#
# merged 202 into 203
#
# merged 9 into 139
#
# merged 60 into 47
#
# merged 260 into 261
#
# merged 195 into 80
#
# merged 76 into 80
#
# merged 305 into 82
#
# merged 149 into 20
#
# merged 427 into 428
#
# merged 368 into 369
#
# merged 331 into 36
#
# merged 28 into 27
#
# merged 248 into 29
#
# Found 0 splits, checked 1/428 clusters, nccg 1
#
# Found 7 splits, checked 101/435 clusters, nccg 48
#
# Found 11 splits, checked 201/439 clusters, nccg 86
#
# Found 20 splits, checked 301/448 clusters, nccg 134
#
# Found 27 splits, checked 401/455 clusters, nccg 172
#
# Found 28 splits, checked 401/456 clusters, nccg 172
#
# Finished splitting. Found 32 splits, checked 460/460 clusters, nccg 196
#
# Removing 483700 spikes below cutoff from rez.
#
# found 224 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 663.76s
#
#
# Spike sorting elapsed time 824.350781917572 s
#  42%|███████████████████████████████████▊                                                  | 10/24 [2:11:50<3:04:33, 791.00s/it]
# DURATION: 1800.1 s -- NUM. CHANNELS: 1005
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well010/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  12s. Loading raw data and applying filters...
#
# Time 215s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.77 sec, 1 batches, 5274 spikes
#
# 66.41 sec, 101 batches, 553182 spikes
#
# 132.04 sec, 201 batches, 1093538 spikes
#
# 180.22 sec, 275 batches, 1487477 spikes
#
# time 187.73, Skipped shifting 275 batches.
#
# Time 192s. Optimizing templates ...
#
# 192.29 sec, 1 / 275 batches, 91 units, nspks: 21.1122, mu: 16.9836, nst0: 306, merges: 0.0000, 0.0000, 4.3000
#
# 231.82 sec, 101 / 275 batches, 394 units, nspks: 2589.3536, mu: 19.3398, nst0: 2058, merges: 282.8494, 0.4250, 64.8897
#
# 270.36 sec, 201 / 275 batches, 396 units, nspks: 2821.5725, mu: 19.5516, nst0: 2203, merges: 329.8932, 0.3419, 67.2094
#
# Elapsed time is 299.387764 seconds.
#
# Finished learning templates
#
# Time 301s. Optimizing templates ...
#
# 301.30 sec, 1 / 275 batches, 320 units, nspks: 2600.0000, mu: 20.4900, nst0: 3419
#
# 327.68 sec, 101 / 275 batches, 320 units, nspks: 280154.0000, mu: 20.4900, nst0: 4381
#
# 354.89 sec, 201 / 275 batches, 320 units, nspks: 555262.0000, mu: 20.4900, nst0: 3234
#
# Elapsed time is 374.402524 seconds.
#
# Number of spikes before applying cutoff: 984426
#
# initialized spike counts
#
# merged 132 into 149
#
# merged 51 into 50
#
# merged 274 into 273
#
# merged 89 into 240
#
# merged 13 into 31
#
# merged 65 into 64
#
# merged 118 into 117
#
# merged 183 into 189
#
# merged 21 into 22
#
# merged 75 into 74
#
# merged 61 into 306
#
# merged 180 into 182
#
# merged 20 into 22
#
# merged 290 into 312
#
# merged 62 into 202
#
# merged 248 into 104
#
# merged 211 into 212
#
# merged 283 into 281
#
# merged 158 into 157
#
# merged 136 into 137
#
# merged 260 into 240
#
# merged 192 into 106
#
# merged 42 into 52
#
# merged 64 into 63
#
# merged 234 into 95
#
# merged 144 into 177
#
# merged 313 into 312
#
# merged 245 into 189
#
# merged 202 into 189
#
# merged 284 into 281
#
# merged 49 into 48
#
# merged 286 into 316
#
# merged 114 into 113
#
# merged 282 into 281
#
# merged 150 into 151
#
# merged 311 into 310
#
# merged 85 into 86
#
# merged 170 into 169
#
# merged 71 into 70
#
# Found 0 splits, checked 1/320 clusters, nccg 0
#
# Found 12 splits, checked 101/332 clusters, nccg 50
#
# Found 23 splits, checked 201/343 clusters, nccg 92
#
# Found 37 splits, checked 301/357 clusters, nccg 131
#
# Found 38 splits, checked 301/358 clusters, nccg 131
#
# Found 39 splits, checked 301/359 clusters, nccg 131
#
# Finished splitting. Found 47 splits, checked 367/367 clusters, nccg 161
#
# Removing 203707 spikes below cutoff from rez.
#
# found 179 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 657.64s
#
#
# Spike sorting elapsed time 816.4857451915741 s
#  46%|███████████████████████████████████████▍                                              | 11/24 [2:25:34<2:53:36, 801.24s/it]
# DURATION: 1800.1 s -- NUM. CHANNELS: 1004
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well011/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time   6s. Loading raw data and applying filters...
#
# Time 161s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.80 sec, 1 batches, 9662 spikes
#
# 67.83 sec, 101 batches, 849724 spikes
#
# 135.60 sec, 201 batches, 1681071 spikes
#
# 186.02 sec, 275 batches, 2294481 spikes
#
# time 194.16, Skipped shifting 275 batches.
#
# Time 198s. Optimizing templates ...
#
# 198.73 sec, 1 / 275 batches, 89 units, nspks: 18.2277, mu: 18.3290, nst0: 251, merges: 0.3000, 0.0000, 4.0000
#
# 239.81 sec, 101 / 275 batches, 428 units, nspks: 4137.8360, mu: 18.3431, nst0: 4703, merges: 266.6708, 1.2631, 62.8995
#
# 281.48 sec, 201 / 275 batches, 444 units, nspks: 4278.0385, mu: 18.0487, nst0: 4703, merges: 339.9907, 0.4764, 71.5838
#
# Elapsed time is 312.219423 seconds.
#
# Finished learning templates
#
# Time 314s. Optimizing templates ...
#
# 314.55 sec, 1 / 275 batches, 357 units, nspks: 4767.0000, mu: 19.1675, nst0: 5939
#
# 343.02 sec, 101 / 275 batches, 357 units, nspks: 414484.0000, mu: 19.1675, nst0: 6298
#
# 372.85 sec, 201 / 275 batches, 357 units, nspks: 824045.0000, mu: 19.1675, nst0: 4632
#
# Elapsed time is 395.302261 seconds.
#
# Number of spikes before applying cutoff: 1423427
#
# initialized spike counts
#
# merged 14 into 13
#
# merged 181 into 179
#
# merged 118 into 169
#
# merged 200 into 210
#
# merged 45 into 125
#
# merged 79 into 20
#
# merged 254 into 55
#
# merged 98 into 96
#
# merged 317 into 316
#
# merged 46 into 125
#
# merged 310 into 265
#
# merged 167 into 166
#
# merged 296 into 295
#
# merged 266 into 265
#
# merged 117 into 190
#
# merged 203 into 89
#
# merged 183 into 182
#
# merged 336 into 337
#
# merged 332 into 333
#
# merged 70 into 68
#
# merged 105 into 104
#
# merged 133 into 138
#
# merged 320 into 319
#
# merged 65 into 66
#
# merged 7 into 6
#
# merged 90 into 89
#
# merged 357 into 356
#
# merged 206 into 207
#
# merged 29 into 143
#
# merged 109 into 257
#
# merged 275 into 274
#
# merged 321 into 265
#
# merged 261 into 262
#
# merged 222 into 221
#
# merged 150 into 149
#
# merged 137 into 138
#
# merged 304 into 303
#
# merged 136 into 138
#
# merged 307 into 308
#
# merged 182 into 302
#
# merged 247 into 248
#
# merged 331 into 333
#
# merged 97 into 52
#
# merged 351 into 350
#
# merged 158 into 157
#
# merged 352 into 350
#
# merged 208 into 209
#
# merged 251 into 252
#
# merged 268 into 267
#
# merged 170 into 169
#
# merged 22 into 23
#
# merged 62 into 63
#
# merged 82 into 81
#
# merged 41 into 40
#
# Found 1 splits, checked 1/358 clusters, nccg 1
#
# Found 8 splits, checked 101/365 clusters, nccg 51
#
# Found 15 splits, checked 201/372 clusters, nccg 82
#
# Found 24 splits, checked 301/381 clusters, nccg 134
#
# Finished splitting. Found 34 splits, checked 391/391 clusters, nccg 178
#
# Removing 264665 spikes below cutoff from rez.
#
# found 206 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 634.59s
#
#
# Spike sorting elapsed time 823.1449227333069 s
#  50%|███████████████████████████████████████████                                           | 12/24 [2:39:26<2:42:06, 810.52s/it]
# DURATION: 1799.98 s -- NUM. CHANNELS: 992
# write_binary_recording:   0%|          | 0/1800 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well012/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 216s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.70 sec, 1 batches, 4950 spikes
#
# 76.99 sec, 101 batches, 803529 spikes
#
# 154.77 sec, 201 batches, 1598528 spikes
#
# 212.43 sec, 275 batches, 2168391 spikes
#
# time 220.29, Skipped shifting 275 batches.
#
# Time 224s. Optimizing templates ...
#
# 224.85 sec, 1 / 275 batches, 58 units, nspks: 18.4695, mu: 10.0000, nst0: 295, merges: 1.5000, 0.0000, 3.2000
#
# 267.57 sec, 101 / 275 batches, 470 units, nspks: 4765.4138, mu: 16.6825, nst0: 5160, merges: 223.3037, 0.3373, 56.4099
#
# 312.34 sec, 201 / 275 batches, 443 units, nspks: 5103.2005, mu: 16.0642, nst0: 5303, merges: 271.2879, 0.1514, 56.1147
#
# Elapsed time is 343.427059 seconds.
#
# Finished learning templates
#
# Time 346s. Optimizing templates ...
#
# 346.11 sec, 1 / 275 batches, 373 units, nspks: 2945.0000, mu: 16.5207, nst0: 3689
#
# 376.48 sec, 101 / 275 batches, 373 units, nspks: 465820.0000, mu: 16.5207, nst0: 6427
#
# 406.85 sec, 201 / 275 batches, 373 units, nspks: 925977.0000, mu: 16.5207, nst0: 6799
#
# Elapsed time is 429.271103 seconds.
#
# Number of spikes before applying cutoff: 1479987
#
# initialized spike counts
#
# merged 60 into 69
#
# merged 306 into 308
#
# merged 236 into 234
#
# merged 155 into 154
#
# merged 262 into 263
#
# merged 237 into 234
#
# merged 203 into 202
#
# merged 41 into 124
#
# merged 175 into 206
#
# merged 244 into 240
#
# merged 150 into 151
#
# merged 235 into 234
#
# merged 291 into 290
#
# merged 95 into 96
#
# merged 362 into 361
#
# merged 10 into 8
#
# merged 148 into 151
#
# merged 229 into 228
#
# merged 183 into 151
#
# merged 133 into 131
#
# merged 242 into 241
#
# merged 222 into 79
#
# merged 243 into 240
#
# merged 292 into 290
#
# merged 365 into 353
#
# merged 16 into 15
#
# merged 132 into 134
#
# merged 197 into 196
#
# merged 99 into 100
#
# merged 134 into 131
#
# merged 112 into 111
#
# merged 14 into 13
#
# merged 21 into 19
#
# merged 195 into 193
#
# merged 342 into 25
#
# merged 289 into 288
#
# merged 193 into 194
#
# merged 119 into 120
#
# merged 173 into 172
#
# Found 0 splits, checked 1/373 clusters, nccg 0
#
# Found 8 splits, checked 101/381 clusters, nccg 53
#
# Found 9 splits, checked 101/382 clusters, nccg 53
#
# Found 14 splits, checked 201/387 clusters, nccg 100
#
# Found 19 splits, checked 301/392 clusters, nccg 150
#
# Finished splitting. Found 25 splits, checked 398/398 clusters, nccg 203
#
# Removing 193292 spikes below cutoff from rez.
#
# found 212 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 729.70s
#
#
# Spike sorting elapsed time 887.4902632236481 s
#  54%|██████████████████████████████████████████████▌                                       | 13/24 [2:54:22<2:33:20, 836.37s/it]
# DURATION: 1799.98 s -- NUM. CHANNELS: 970
# write_binary_recording:   0%|          | 0/1800 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well013/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 206s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.71 sec, 1 batches, 10000 spikes
#
# 65.15 sec, 101 batches, 881218 spikes
#
# 130.20 sec, 201 batches, 1739709 spikes
#
# 178.92 sec, 275 batches, 2366867 spikes
#
# time 186.87, Skipped shifting 275 batches.
#
# Time 191s. Optimizing templates ...
#
# 191.13 sec, 1 / 275 batches, 2 units, nspks: 0.1779, mu: 14.2458, nst0: 1, merges: 0.0000, 0.0000, 0.1000
#
# 231.52 sec, 101 / 275 batches, 477 units, nspks: 3897.5697, mu: 17.7713, nst0: 5175, merges: 300.8026, 0.4180, 73.4057
#
# 272.23 sec, 201 / 275 batches, 438 units, nspks: 4300.7688, mu: 15.8014, nst0: 4370, merges: 357.3833, 0.3107, 75.6710
#
# Elapsed time is 302.087343 seconds.
#
# Finished learning templates
#
# Time 304s. Optimizing templates ...
#
# 304.32 sec, 1 / 275 batches, 344 units, nspks: 5263.0000, mu: 16.8438, nst0: 7034
#
# 333.19 sec, 101 / 275 batches, 344 units, nspks: 431053.0000, mu: 16.8438, nst0: 3275
#
# 362.33 sec, 201 / 275 batches, 344 units, nspks: 851574.0000, mu: 16.8438, nst0: 6435
#
# Elapsed time is 384.101585 seconds.
#
# Number of spikes before applying cutoff: 1629496
#
# initialized spike counts
#
# merged 235 into 234
#
# merged 20 into 19
#
# merged 208 into 206
#
# merged 218 into 217
#
# merged 257 into 290
#
# merged 322 into 321
#
# merged 168 into 181
#
# merged 337 into 338
#
# merged 134 into 59
#
# merged 49 into 90
#
# merged 87 into 88
#
# merged 189 into 190
#
# merged 157 into 271
#
# merged 142 into 141
#
# merged 207 into 206
#
# merged 230 into 229
#
# merged 95 into 96
#
# merged 73 into 140
#
# ...
#
# merged 203 into 204
#
# merged 195 into 265
#
# merged 72 into 71
#
# merged 169 into 170
#
# merged 33 into 34
#
# merged 31 into 140
#
# merged 189 into 188
#
# merged 100 into 99
#
# merged 266 into 265
#
# merged 130 into 132
#
# merged 22 into 24
#
# merged 24 into 23
#
# merged 236 into 235
#
# merged 52 into 191
#
# merged 197 into 199
#
# merged 6 into 211
#
# merged 74 into 90
#
# merged 270 into 244
#
# merged 242 into 245
#
# merged 223 into 202
#
# merged 175 into 186
#
# Found 1 splits, checked 1/274 clusters, nccg 1
#
# Found 2 splits, checked 1/275 clusters, nccg 1
#
# Found 19 splits, checked 101/292 clusters, nccg 43
#
# Found 20 splits, checked 101/293 clusters, nccg 43
#
# Found 24 splits, checked 201/297 clusters, nccg 80
#
# Found 33 splits, checked 301/306 clusters, nccg 135
#
# Finished splitting. Found 34 splits, checked 307/307 clusters, nccg 140
#
# Removing 769575 spikes below cutoff from rez.
#
# found 166 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 720.67s
#
#
# Spike sorting elapsed time 881.6837522983551 s
#  83%|█████████████████████████████████████████████████████████████████████████▎              | 20/24 [4:30:55<54:56, 824.18s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 994
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well020/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 201s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.77 sec, 1 batches, 2181 spikes
#
# 67.40 sec, 101 batches, 772969 spikes
#
# 133.57 sec, 201 batches, 1535864 spikes
#
# 182.78 sec, 275 batches, 2083377 spikes
#
# time 190.71, Skipped shifting 275 batches.
#
# Time 195s. Optimizing templates ...
#
# 195.14 sec, 1 / 275 batches, 49 units, nspks: 4.9258, mu: 14.8304, nst0: 36, merges: 0.8000, 0.0000, 2.2000
#
# 232.76 sec, 101 / 275 batches, 316 units, nspks: 3801.3242, mu: 17.2287, nst0: 3375, merges: 175.4105, 1.2949, 45.5538
#
# 270.95 sec, 201 / 275 batches, 332 units, nspks: 3897.4409, mu: 16.3211, nst0: 4431, merges: 242.0730, 0.6625, 52.3451
#
# Elapsed time is 299.359074 seconds.
#
# Finished learning templates
#
# Time 301s. Optimizing templates ...
#
# 301.14 sec, 1 / 275 batches, 303 units, nspks: 914.0000, mu: 17.7022, nst0: 1297
#
# 330.91 sec, 101 / 275 batches, 303 units, nspks: 415110.0000, mu: 17.7022, nst0: 4193
#
# 360.68 sec, 201 / 275 batches, 303 units, nspks: 822411.0000, mu: 17.7022, nst0: 6498
#
# Elapsed time is 380.813316 seconds.
#
# Number of spikes before applying cutoff: 1541011
#
# initialized spike counts
#
# merged 252 into 251
#
# merged 108 into 112
#
# merged 160 into 161
#
# merged 69 into 123
#
# merged 24 into 25
#
# merged 100 into 87
#
# merged 254 into 249
#
# merged 253 into 249
#
# merged 140 into 112
#
# merged 52 into 14
#
# merged 220 into 219
#
# merged 207 into 209
#
# merged 51 into 15
#
# merged 4 into 5
#
# merged 185 into 187
#
# merged 10 into 9
#
# merged 230 into 229
#
# merged 206 into 208
#
# merged 216 into 214
#
# merged 72 into 76
#
# merged 139 into 112
#
# merged 278 into 275
#
# merged 16 into 54
#
# merged 238 into 36
#
# merged 53 into 15
#
# merged 250 into 251
#
# merged 147 into 146
#
# merged 120 into 121
#
# merged 55 into 54
#
# merged 74 into 75
#
# merged 18 into 17
#
# merged 12 into 13
#
# merged 17 into 15
#
# merged 208 into 209
#
# merged 213 into 212
#
# merged 13 into 54
#
# merged 85 into 152
#
# merged 183 into 186
#
# merged 14 into 15
#
# merged 75 into 70
#
# merged 186 into 187
#
# merged 163 into 240
#
# merged 249 into 248
#
# merged 188 into 187
#
# merged 76 into 70
#
# merged 211 into 209
#
# Found 0 splits, checked 1/303 clusters, nccg 1
#
# Found 7 splits, checked 101/310 clusters, nccg 48
#
# Found 11 splits, checked 201/314 clusters, nccg 82
#
# Found 19 splits, checked 301/322 clusters, nccg 119
#
# Finished splitting. Found 19 splits, checked 322/322 clusters, nccg 133
#
# Removing 329456 spikes below cutoff from rez.
#
# found 158 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 653.33s
#
#
# Spike sorting elapsed time 817.695024728775 s
#  88%|█████████████████████████████████████████████████████████████████████████████           | 21/24 [4:44:42<41:14, 824.86s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 997
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well021/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  11s. Loading raw data and applying filters...
#
# Time 214s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.72 sec, 1 batches, 5203 spikes
#
# 67.80 sec, 101 batches, 505240 spikes
#
# 135.92 sec, 201 batches, 1004195 spikes
#
# 186.33 sec, 275 batches, 1368166 spikes
#
# time 193.52, Skipped shifting 275 batches.
#
# Time 198s. Optimizing templates ...
#
# 198.17 sec, 1 / 275 batches, 102 units, nspks: 28.8739, mu: 12.1439, nst0: 447, merges: 0.3000, 0.0000, 5.1000
#
# 237.83 sec, 101 / 275 batches, 324 units, nspks: 2494.8415, mu: 16.6003, nst0: 2256, merges: 267.4562, 2.2459, 62.7195
#
# 277.31 sec, 201 / 275 batches, 321 units, nspks: 2767.4503, mu: 15.8086, nst0: 2652, merges: 315.2948, 0.9976, 64.0990
#
# Elapsed time is 306.158884 seconds.
#
# Finished learning templates
#
# Time 307s. Optimizing templates ...
#
# 307.25 sec, 1 / 275 batches, 232 units, nspks: 2869.0000, mu: 16.8436, nst0: 4997
#
# 334.38 sec, 101 / 275 batches, 232 units, nspks: 278924.0000, mu: 16.8436, nst0: 4278
#
# 363.70 sec, 201 / 275 batches, 232 units, nspks: 555695.0000, mu: 16.8436, nst0: 6875
#
# Elapsed time is 385.358518 seconds.
#
# Number of spikes before applying cutoff: 1319745
#
# initialized spike counts
#
# merged 53 into 14
#
# merged 195 into 207
#
# merged 189 into 102
#
# merged 215 into 214
#
# merged 103 into 104
#
# merged 69 into 70
#
# merged 91 into 90
#
# merged 221 into 222
#
# merged 151 into 207
#
# merged 202 into 201
#
# merged 194 into 207
#
# merged 54 into 87
#
# merged 62 into 128
#
# merged 61 into 183
#
# merged 191 into 190
#
# merged 208 into 209
#
# merged 117 into 118
#
# merged 87 into 14
#
# merged 124 into 126
#
# merged 128 into 183
#
# merged 223 into 222
#
# merged 120 into 119
#
# merged 187 into 188
#
# merged 160 into 159
#
# merged 157 into 19
#
# Found 0 splits, checked 1/232 clusters, nccg 0
#
# Found 6 splits, checked 101/238 clusters, nccg 31
#
# Found 10 splits, checked 201/242 clusters, nccg 62
#
# Finished splitting. Found 12 splits, checked 244/244 clusters, nccg 80
#
# Removing 445008 spikes below cutoff from rez.
#
# found 93 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 658.32s
#
#
# Spike sorting elapsed time 821.2998292446136 s
#  92%|████████████████████████████████████████████████████████████████████████████████▋       | 22/24 [4:58:32<27:33, 826.56s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 1006
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well022/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  12s. Loading raw data and applying filters...
#
# Time 215s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.78 sec, 1 batches, 9772 spikes
#
# 67.42 sec, 101 batches, 842422 spikes
#
# 134.55 sec, 201 batches, 1657579 spikes
#
# 184.96 sec, 275 batches, 2262991 spikes
#
# time 192.96, Skipped shifting 275 batches.
#
# Time 197s. Optimizing templates ...
#
# 197.62 sec, 1 / 275 batches, 86 units, nspks: 10.4342, mu: 16.9097, nst0: 99, merges: 0.4000, 0.0000, 3.8000
#
# 238.23 sec, 101 / 275 batches, 414 units, nspks: 3734.0310, mu: 17.7365, nst0: 3923, merges: 300.1409, 0.5140, 71.5997
#
# 280.28 sec, 201 / 275 batches, 445 units, nspks: 4210.9349, mu: 17.7443, nst0: 4725, merges: 359.8762, 0.2873, 73.0392
#
# Elapsed time is 311.289582 seconds.
#
# Finished learning templates
#
# Time 313s. Optimizing templates ...
#
# 313.44 sec, 1 / 275 batches, 341 units, nspks: 4660.0000, mu: 18.1321, nst0: 6878
#
# 341.57 sec, 101 / 275 batches, 341 units, nspks: 412584.0000, mu: 18.1321, nst0: 6236
#
# 370.73 sec, 201 / 275 batches, 341 units, nspks: 814511.0000, mu: 18.1321, nst0: 916
#
# Elapsed time is 392.545785 seconds.
#
# Number of spikes before applying cutoff: 1632918
#
# initialized spike counts
#
# merged 60 into 111
#
# merged 160 into 159
#
# merged 274 into 273
#
# merged 233 into 232
#
# merged 161 into 159
#
# merged 219 into 218
#
# merged 23 into 24
#
# merged 225 into 223
#
# merged 211 into 210
#
# merged 325 into 326
#
# merged 156 into 158
#
# merged 300 into 317
#
# merged 58 into 59
#
# merged 12 into 13
#
# merged 229 into 146
#
# merged 248 into 117
#
# merged 98 into 155
#
# merged 100 into 155
#
# merged 231 into 232
#
# merged 265 into 264
#
# merged 4 into 2
#
# merged 174 into 173
#
# merged 189 into 200
#
# merged 124 into 125
#
# merged 224 into 223
#
# merged 50 into 51
#
# merged 16 into 17
#
# merged 74 into 75
#
# merged 151 into 153
#
# merged 172 into 168
#
# merged 168 into 173
#
# merged 276 into 176
#
# merged 128 into 127
#
# merged 126 into 173
#
# merged 157 into 158
#
# merged 203 into 202
#
# merged 66 into 65
#
# merged 112 into 113
#
# merged 235 into 260
#
# merged 155 into 99
#
# merged 123 into 125
#
# merged 181 into 267
#
# merged 319 into 327
#
# merged 146 into 227
#
# merged 178 into 177
#
# merged 84 into 87
#
# merged 5 into 6
#
# merged 21 into 114
#
# merged 116 into 118
#
# merged 120 into 182
#
# merged 261 into 260
#
# Found 0 splits, checked 1/341 clusters, nccg 0
#
# Found 6 splits, checked 101/347 clusters, nccg 35
#
# Found 11 splits, checked 201/352 clusters, nccg 71
#
# Found 16 splits, checked 301/357 clusters, nccg 118
#
# Finished splitting. Found 17 splits, checked 358/358 clusters, nccg 143
#
# Removing 452904 spikes below cutoff from rez.
#
# found 176 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 682.91s
# /home/phornauer/si_test/spikeinterface/src/spikeinterface/core/basesorting.py:176: UserWarning: Some spikes exceed the recording's duration! Removing these excess spikes with `spikeinterface.curation.remove_excess_spikes()` Might be necessary for further postprocessing.
#   warnings.warn(
# Spike sorting elapsed time 853.3549299240112 s
#  96%|████████████████████████████████████████████████████████████████████████████████████▎   | 23/24 [5:12:54<13:57, 837.11s/it]
# DURATION: 1800.06 s -- NUM. CHANNELS: 1003
# write_binary_recording:   0%|          | 0/1801 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /net/bs-filesvr02/export/group/hierlemann/intermediate_data/Maxtwo/phornauer/Torsten/240823/T002523/Network/well023/sorter_output/run_kilosort2_5.sh
#
#
#                                                                               < M A T L A B (R) >
#
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#
#                                                                     R2020b (9.9.0.1467703) 64-bit (glnxa64)
#
#                                                                                 August 26, 2020
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Time   1s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time  12s. Loading raw data and applying filters...
#
# Time 216s. Finished preprocessing 275 batches.
#
# Drift correction DISABLED
#
# pitch is 1.750000e+01 um
#
# 0.70 sec, 1 batches, 10000 spikes
#
# 66.80 sec, 101 batches, 979232 spikes
#
# 133.83 sec, 201 batches, 1949033 spikes
#
# 183.88 sec, 275 batches, 2652593 spikes
#
# time 192.08, Skipped shifting 275 batches.
#
# Time 196s. Optimizing templates ...
#
# 196.81 sec, 1 / 275 batches, 159 units, nspks: 52.4311, mu: 10.0000, nst0: 845, merges: 0.1000, 0.0000, 8.3000
#
# 244.49 sec, 101 / 275 batches, 472 units, nspks: 5227.3023, mu: 17.1704, nst0: 7238, merges: 397.5168, 0.5282, 92.0448
#
# 290.39 sec, 201 / 275 batches, 447 units, nspks: 6230.6674, mu: 15.1772, nst0: 4090, merges: 450.0342, 0.1892, 92.1230
#
# Elapsed time is 325.717639 seconds.
#
# Finished learning templates
#
# Time 328s. Optimizing templates ...
#
# 327.91 sec, 1 / 275 batches, 334 units, nspks: 7643.0000, mu: 16.4007, nst0: 10897
#
# 360.63 sec, 101 / 275 batches, 334 units, nspks: 611999.0000, mu: 16.4007, nst0: 10105
#
# 394.24 sec, 201 / 275 batches, 334 units, nspks: 1218357.0000, mu: 16.4007, nst0: 11079
#
# Elapsed time is 419.074925 seconds.
#
# Number of spikes before applying cutoff: 2474993
#
# initialized spike counts
#
# merged 69 into 83
#
# merged 144 into 193
#
# merged 94 into 8
#
# merged 104 into 103
#
# merged 88 into 87
#
# merged 194 into 193
#
# merged 152 into 151
#
# merged 273 into 305
#
# merged 67 into 68
#
# merged 141 into 142
#
# merged 202 into 56
#
# merged 155 into 184
#
# merged 11 into 10
#
# merged 311 into 259
#
# merged 137 into 136
#
# merged 138 into 136
#
# merged 123 into 122
#
# merged 196 into 198
#
# merged 307 into 308
#
# merged 71 into 72
#
# merged 328 into 327
#
# merged 53 into 102
#
# merged 231 into 210
#
# merged 78 into 77
#
# merged 284 into 285
#
# merged 286 into 285
#
# merged 93 into 95
#
# merged 107 into 159
#
# merged 240 into 241
#
# merged 282 into 281
#
# merged 211 into 212
#
# merged 317 into 281
#
# merged 156 into 29
#
# merged 262 into 261
#
# merged 306 into 305
#
# merged 75 into 163
#
# merged 9 into 10
#
# merged 62 into 61
#
# merged 52 into 92
#
# merged 39 into 40
#
# merged 332 into 331
#
# merged 25 into 24
#
# merged 1 into 64
#
# merged 113 into 114
#
# merged 124 into 125
#
# merged 91 into 24
#
# Found 0 splits, checked 1/334 clusters, nccg 0
#
# Found 24 splits, checked 101/358 clusters, nccg 45
#
# Found 25 splits, checked 101/359 clusters, nccg 45
#
# Found 26 splits, checked 101/360 clusters, nccg 45
#
# Found 27 splits, checked 101/361 clusters, nccg 45
#
# Found 36 splits, checked 201/370 clusters, nccg 102
#
# Found 45 splits, checked 301/379 clusters, nccg 156
#
# Found 46 splits, checked 301/380 clusters, nccg 156
#
# Finished splitting. Found 52 splits, checked 386/386 clusters, nccg 207
#
# Removing 596443 spikes below cutoff from rez.
#
# found 229 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 736.88s
#
#
# Spike sorting elapsed time 907.0552577972412 s
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 24/24 [5:28:10<00:00, 820.44s/it]
